# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Numerical features

# %%
df=sns.load_dataset("TIPS")

# %%
df=sns.load_dataset

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (244, 7)

# %%
print(sns.get_dataset_names())
# Out:
# ['anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'iris', 'mpg', 'planets', 'tips', 'titanic']

# %%
df.corr()# works only for continous features
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.jointplot(x='tip',y='total_bill',data=df)

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')# draws a regression line and a probability distribution

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='smoker')

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
a=sns.distplot(df.get('tip'))
plt.show()

# %% [markdown]
# # Categorial fetures plotting

# %%
sns.countplot('sex',data=df)

# %%
sns.countplot('smoker',data=df)

# %%
sns.boxplot(x='smoker',y='tip',data=df)

# %%
sns.countplot(y='smoker',data=df)

# %%
sns.boxplot(x='sex',y='tip',data=df)

# %%
l=list(zip(df.get('tip').values,df.get('sex').values))

# %%
l
# Out:
# [(1.01, 'Female'),
#  (1.66, 'Male'),
#  (3.5, 'Male'),
#  (3.31, 'Male'),
#  (3.61, 'Female'),
#  (4.71, 'Male'),
#  (2.0, 'Male'),
#  (3.12, 'Male'),
#  (1.96, 'Male'),
#  (3.23, 'Male'),
#  (1.71, 'Male'),
#  (5.0, 'Female'),
#  (1.57, 'Male'),
#  (3.0, 'Male'),
#  (3.02, 'Female'),
#  (3.92, 'Male'),
#  (1.67, 'Female'),
#  (3.71, 'Male'),
#  (3.5, 'Female'),
#  (3.35, 'Male'),
#  (4.08, 'Male'),
#  (2.75, 'Female'),
#  (2.23, 'Female'),
#  (7.58, 'Male'),
#  (3.18, 'Male'),
#  (2.34, 'Male'),
#  (2.0, 'Male'),
#  (2.0, 'Male'),
#  (4.3, 'Male'),
#  (3.0, 'Female'),
#  (1.45, 'Male'),
#  (2.5, 'Male'),
#  (3.0, 'Female'),
#  (2.45, 'Female'),
#  (3.27, 'Male'),
#  (3.6, 'Male'),
#  (2.0, 'Male'),
#  (3.07, 'Female'),
#  (2.31, 'Male'),
#  (5.0, 'Male'),
#  (2.24, 'Male'),
#  (2.54, 'Male'),
#  (3.06, 'Male'),
#  (1.32, 'Male'),
#  (5.6, 'Male'),
#  (3.0, 'Male'),
#  (5.0, 'Male'),
#  (6.0, 'Male'),
#  (2.05, 'Male'),
#  (3.0, 'Male'),
#  (2.5, 'Male'),
#  (2.6, 'Female'),
# ...

# %%
sns.barplot(x='sex',y='tip',data=df)

# %%
sns.boxplot(x='smoker',y='tip',data=df)

# %%
sns.boxplot(x='day',y='tip',data=df,hue='smoker')
